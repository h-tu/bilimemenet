# %%
# !git clone https://github.com/dbiir/UER-py.git
# Out:
# fatal: destination path 'UER-py' already exists and is not an empty directory.

# %%
#https://drive.google.com/file/d/1M0pbCF2eaD4h3oqE4amEaRTQ1auehBNY/view?usp=sharing
# !gdown 1M0pbCF2eaD4h3oqE4amEaRTQ1auehBNY
#https://drive.google.com/file/d/1j0u_NrfnNOhZVja4SbgxRBCL_xxzJwif/view?usp=sharing
# !gdown 1j0u_NrfnNOhZVja4SbgxRBCL_xxzJwif
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M0pbCF2eaD4h3oqE4amEaRTQ1auehBNY
# To: /content/UER-py/UER_ROBert_input.txt
# 100% 2.34M/2.34M [00:00<00:00, 212MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1j0u_NrfnNOhZVja4SbgxRBCL_xxzJwif
# To: /content/UER-py/UER_RoBert_danmu_data.zip
# 100% 1.28M/1.28M [00:00<00:00, 163MB/s]

# %%
# !mv UER_RoBert_danmu_data.zip UER-py/
# %cd UER-py/
# !unzip UER_RoBert_danmu_data.zip
# Out:
# mv: failed to access 'UER-py/': Not a directory
# [Errno 20] Not a directory: 'UER-py/'
# /content/UER-py
# Archive:  UER_RoBert_danmu_data.zip
#   inflating: UER_ROBert_input_val.tsv
#   inflating: UER_ROBert_input_test.tsv
#   inflating: UER_ROBert_input_train.tsv

# %%
# !git lfs clone https://huggingface.co/uer/chinese_roberta_L-12_H-768
# Out:
# WARNING: 'git lfs clone' is deprecated and will not be updated
#           with new flags from 'git clone'
#
# 'git clone' has been updated in upstream Git to have comparable
# speeds to 'git lfs clone'.
# Cloning into 'chinese_roberta_L-12_H-768'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 54 (delta 25), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (54/54), done.
# Git LFS: (3 of 3 files) 1.21 GB / 1.21 GB

# %%
# %cd /content/UER-py
# Out:
# /content/UER-py

# %%
# !python3 finetune/run_classifier.py --pretrained_model_path chinese_roberta_L-12_H-768/pytorch_model.bin \
                  --vocab_path models/google_zh_vocab.txt \
                  --config_path models/bert/base_config.json \
                  --train_path UER_ROBert_input_train.tsv \
                  --dev_path UER_ROBert_input_val.tsv \
                  --test_path UER_ROBert_input_test.tsv \
                  --epochs_num 1 --batch_size 64
# Out:
# [2022-05-12 13:13:22,235 INFO] Batch size: 64
# [2022-05-12 13:13:22,235 INFO] The number of training instances: 107985
# [2022-05-12 13:13:22,236 INFO] Start training.
# [2022-05-12 13:14:42,581 INFO] Epoch id: 1, Training steps: 100, Avg loss: 1.702
# [2022-05-12 13:16:02,237 INFO] Epoch id: 1, Training steps: 200, Avg loss: 1.661
# [2022-05-12 13:17:21,922 INFO] Epoch id: 1, Training steps: 300, Avg loss: 1.642
# [2022-05-12 13:18:41,605 INFO] Epoch id: 1, Training steps: 400, Avg loss: 1.639
# [2022-05-12 13:20:01,331 INFO] Epoch id: 1, Training steps: 500, Avg loss: 1.621
# [2022-05-12 13:21:21,081 INFO] Epoch id: 1, Training steps: 600, Avg loss: 1.600
# [2022-05-12 13:22:40,783 INFO] Epoch id: 1, Training steps: 700, Avg loss: 1.584
# [2022-05-12 13:24:00,587 INFO] Epoch id: 1, Training steps: 800, Avg loss: 1.598
# [2022-05-12 13:25:20,435 INFO] Epoch id: 1, Training steps: 900, Avg loss: 1.575
# [2022-05-12 13:26:40,280 INFO] Epoch id: 1, Training steps: 1000, Avg loss: 1.574
# [2022-05-12 13:28:00,087 INFO] Epoch id: 1, Training steps: 1100, Avg loss: 1.563
# [2022-05-12 13:29:19,893 INFO] Epoch id: 1, Training steps: 1200, Avg loss: 1.548
# [2022-05-12 13:30:39,715 INFO] Epoch id: 1, Training steps: 1300, Avg loss: 1.572
# [2022-05-12 13:31:59,562 INFO] Epoch id: 1, Training steps: 1400, Avg loss: 1.540
# [2022-05-12 13:33:19,431 INFO] Epoch id: 1, Training steps: 1500, Avg loss: 1.551
# [2022-05-12 13:34:39,264 INFO] Epoch id: 1, Training steps: 1600, Avg loss: 1.541
