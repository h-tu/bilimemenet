# %% [markdown]
# # Get Data Ready

# %%
#!pip install gdown

# %%
#https://drive.google.com/file/d/1hTp8qDF4r2tTk7W6SBnfYyRoNwwSdkap/view?usp=sharing
# !gdown --id 1hTp8qDF4r2tTk7W6SBnfYyRoNwwSdkap
#https://drive.google.com/file/d/1T-yZGWyPC89SCCbm1m0DrRMGyDlUaonl/view?usp=sharing
# !gdown --id 1T-yZGWyPC89SCCbm1m0DrRMGyDlUaonl
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1hTp8qDF4r2tTk7W6SBnfYyRoNwwSdkap
# To: /home/ec2-user/SageMaker/danmu_token_main.pkl
# 100%|███████████████████████████████████████| 5.38M/5.38M [00:00<00:00, 143MB/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1T-yZGWyPC89SCCbm1m0DrRMGyDlUaonl
# To: /home/ec2-user/SageMaker/danmu_dist_main.pkl
# 100%|███████████████████████████████████████| 56.7M/56.7M [00:00<00:00, 252MB/s]

# %%
import pickle

token_file = open("danmu_token_main.pkl", "rb")
dist_file = open("danmu_dist_main.pkl", "rb")

tokens = pickle.load(token_file)
dists = pickle.load(dist_file)

print(len(tokens))
print(len(dists))
# Out:
# 337392
# 337392

# %%
import numpy as np
labels = [np.argmax(i) for i in dists]

label_distribution = {}
for i in labels:
    if i in label_distribution:
        label_distribution[i] += 1
    else:
        label_distribution[i] = 1

# %%
len(label_distribution)
# Out:
# 19

# %%
# remove label with no data
label_list = list(label_distribution.keys())
labels = [label_list.index(i) for i in labels]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.DataFrame({
    'text': tokens,
    'label': labels
})

train_df, test_df = train_test_split(df, test_size=0.2)
train_df, val_df = train_test_split(train_df, test_size=0.1)

# %%
#Debugging
train_df = train_df[train_df['text'] != 'nan']
test_df = test_df[test_df['text'] != 'nan']
val_df = val_df[val_df['text'] != 'nan']

# %%
train_df.reset_index(drop=True)
test_df.reset_index(drop=True)
val_df.reset_index(drop=True)
# Out:
#           text  label
# 0          自吸换     13
# 1        再见了朋友      0
# 2        哈哈蔡依林      3
# 3          一波盲      9
# 4          这中单      2
# ...        ...    ...
# 26987      逍遥散      2
# 26988    50g冲浪     12
# 26989     发条茉莉      4
# 26990  glasgow      6
# 26991      带耳机      3
#
# [26992 rows x 2 columns]

# %%
#save to csv

train_df = train_df.dropna()
test_df = test_df.dropna()
val_df = val_df.dropna()

train_df.to_csv('data_csv/train.csv', index = False)
test_df.to_csv('data_csv/test.csv', index = False)
val_df.to_csv('data_csv/val.csv', index = False)

# train_dict = train_df.to_dict()
# test_dict = test_df.to_dict()
# val_dict = val_df.to_dict()
# train_data_json = {
#     'train' : train_dict,
#     'test' : test_dict,
#     'validation': val_dict
# }

# import json

# with open('data_csv/data.json', 'w') as f:
#     json.dump(train_data_json, f)

# %% [markdown]
# # Preprocessing

# %%
import datasets
train = datasets.Dataset.from_pandas(train_df, preserve_index=False)
val = datasets.Dataset.from_pandas(val_df, preserve_index=False)
test = datasets.Dataset.from_pandas(test_df, preserve_index=False)

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-chinese")

def preprocess_function(examples):
    return tokenizer(examples["text"], truncation=True)

# %%
#Tokenization

tokenized_train =  train.map(preprocess_function, batched=True)
tokenized_val =  val.map(preprocess_function, batched=True)
tokenized_test = test.map(preprocess_function, batched=True)
# Out:
#   0%|          | 0/243 [00:00<?, ?ba/s]
#   0%|          | 0/27 [00:00<?, ?ba/s]
#   0%|          | 0/68 [00:00<?, ?ba/s]

# %%
# For batching and padding
import transformers 

data_collator = transformers.DataCollatorWithPadding(tokenizer=tokenizer)

# %%
#!conda install pytorch torchvision torchaudio cpuonly -c pytorch

# %% [markdown]
# # Model

# %%
# model = transformers.AutoModelForSequenceClassification.from_pretrained("uer/roberta-base-finetuned-jd-full-chinese",\
#                                                                         num_labels = len(label_distribution), \
#                                                                        ignore_mismatched_sizes=True)
model = transformers.AutoModelForSequenceClassification.from_pretrained("bert-base-chinese", num_labels = len(label_distribution))

training_args = transformers.TrainingArguments(
    output_dir="chinese_base",
    
)
# Out:
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-chinese and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#metrics

import numpy as np
from datasets import load_metric

metric = load_metric("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %%
trainer = transformers.Trainer(
    model = model,
    args = training_args,
    train_dataset = tokenized_train,
    eval_dataset = tokenized_val,
    data_collator=data_collator,
    tokenizer = tokenizer,
)

# %%
#trainer.train()

# %% [markdown]
# # SageMaker

# %%
import sagemaker

session = sagemaker.Session()

session_bucket = None
if session_bucket == None and session is not None:
    session_bucket = session.default_bucket()
    
role = sagemaker.get_execution_role()
session = sagemaker.Session(default_bucket = session_bucket)

print(f'role: {role}')
print(f'bucket: {session_bucket}')
print(f'session region: {session.boto_region_name}')
# Out:
# role: arn:aws:iam::635837196364:role/service-role/AmazonSageMaker-ExecutionRole-20220511T210233
# bucket: sagemaker-us-east-1-635837196364
# session region: us-east-1

# %% [markdown]
# Upload to S3 bucket

# %%
import botocore
from datasets.filesystems import S3FileSystem

s3 = S3FileSystem()
s3_prefix = 'dataset/danmu_main'

#save data to S3
train_input_path = f's3://{session.default_bucket()}/{s3_prefix}/train'
#train_dataset.save_to_disk(train_input_path, fs = s3)
session.upload_data(path='data_csv/train.csv', bucket=session_bucket, key_prefix=s3_prefix+'/train')

test_input_path = f's3://{session.default_bucket()}/{s3_prefix}/test'
#test_dataset.save_to_disk(test_input_path, fs = s3)
session.upload_data(path='data_csv/test.csv', bucket=session_bucket, key_prefix=s3_prefix+'/test')

val_input_path = f's3://{session.default_bucket()}/{s3_prefix}/val'
session.upload_data(path='data_csv/val.csv', bucket=session_bucket, key_prefix=s3_prefix+'/val')
# Out:
# 's3://sagemaker-us-east-1-635837196364/dataset/danmu_main/val/val.csv'

# %%
import sagemaker
from sagemaker.huggingface import HuggingFace

# gets role for executing training job

hyperparameters = {
    'model_name_or_path':'bert-base-chinese',
    'output_dir':'/opt/ml/model/bert_base_chinese',
    # add your remaining hyperparameters 
    # more info here https://github.com/huggingface/transformers/tree/v4.17.0/examples/pytorch/text-classification
    'max_seq_length':128,
    'per_device_train_batch_size' : 24,
    'learning_rate' : 2e-5,
    'num_train_epochs': 5,
    #train
    'do_train': True,
    #'do_eval' : True,
    #data
    'train_file': '/opt/ml/input/data/train/train.csv',
    #'test_file': '/opt/ml/input/data/train/test.csv',
    'validation_file': '/opt/ml/input/data/val/val.csv',
}

# %%
# git configuration to download our fine-tuning script
git_config = {'repo': 'https://github.com/huggingface/transformers.git','branch': 'v4.17.0'}

# creates Hugging Face estimator
huggingface_estimator = HuggingFace(
    #entry_point='run_glue_t5.py',
    entry_point='run_glue.py',
    #source_dir='./examples/pytorch/text-classification',
    source_dir = './scripts',
    instance_type='ml.g5.xlarge',
    instance_count=1,
    role=role,
    #it_config=git_config,
    transformers_version='4.17.0',
    pytorch_version='1.10.2',
    py_version='py38',
    hyperparameters = hyperparameters
)

# %%
# starting the train job
huggingface_estimator.fit({'train': train_input_path, 'test': test_input_path, 'val':val_input_path})
# Out:
# 2022-05-12 02:25:21 Starting - Starting the training job...
# 2022-05-12 02:25:44 Starting - Preparing the instances for trainingProfilerReport-1652322320: InProgress
# ......
# 2022-05-12 02:26:50 Downloading - Downloading input data...
# 2022-05-12 02:27:10 Training - Downloading the training image...........................
# 2022-05-12 02:31:46 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-05-12 02:31:39,620 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-05-12 02:31:39,640 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-05-12 02:31:39,646 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-05-12 02:31:40,191 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train",
#         "val": "/opt/ml/input/data/val"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "do_train": true,
#         "learning_rate": 2e-05,
#         "max_seq_length": 128,
#         "model_name_or_path": "bert-base-chinese",
#         "num_train_epochs": 5,
#         "output_dir": "/opt/ml/model/bert_base_chinese",
#         "per_device_train_batch_size": 24,
#         "train_file": "/opt/ml/input/data/train/train.csv",
#         "validation_file": "/opt/ml/input/data/val/val.csv"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "val": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "huggingface-pytorch-training-2022-05-12-02-25-20-722",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-635837196364/huggingface-pytorch-training-2022-05-12-02-25-20-722/source/sourcedir.tar.gz",
#     "module_name": "run_glue",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g5.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "run_glue.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"do_train":true,"learning_rate":2e-05,"max_seq_length":128,"model_name_or_path":"bert-base-chinese","num_train_epochs":5,"output_dir":"/opt/ml/model/bert_base_chinese","per_device_train_batch_size":24,"train_file":"/opt/ml/input/data/train/train.csv","validation_file":"/opt/ml/input/data/val/val.csv"}
# SM_USER_ENTRY_POINT=run_glue.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"val":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train","val"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=run_glue
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-635837196364/huggingface-pytorch-training-2022-05-12-02-25-20-722/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train","val":"/opt/ml/input/data/val"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"do_train":true,"learning_rate":2e-05,"max_seq_length":128,"model_name_or_path":"bert-base-chinese","num_train_epochs":5,"output_dir":"/opt/ml/model/bert_base_chinese","per_device_train_batch_size":24,"train_file":"/opt/ml/input/data/train/train.csv","validation_file":"/opt/ml/input/data/val/val.csv"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"val":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"huggingface-pytorch-training-2022-05-12-02-25-20-722","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-635837196364/huggingface-pytorch-training-2022-05-12-02-25-20-722/source/sourcedir.tar.gz","module_name":"run_glue","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"run_glue.py"}
# SM_USER_ARGS=["--do_train","True","--learning_rate","2e-05","--max_seq_length","128","--model_name_or_path","bert-base-chinese","--num_train_epochs","5","--output_dir","/opt/ml/model/bert_base_chinese","--per_device_train_batch_size","24","--train_file","/opt/ml/input/data/train/train.csv","--validation_file","/opt/ml/input/data/val/val.csv"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CHANNEL_VAL=/opt/ml/input/data/val
# SM_HP_DO_TRAIN=true
# SM_HP_LEARNING_RATE=2e-05
# SM_HP_MAX_SEQ_LENGTH=128
# SM_HP_MODEL_NAME_OR_PATH=bert-base-chinese
# SM_HP_NUM_TRAIN_EPOCHS=5
# SM_HP_OUTPUT_DIR=/opt/ml/model/bert_base_chinese
# SM_HP_PER_DEVICE_TRAIN_BATCH_SIZE=24
# SM_HP_TRAIN_FILE=/opt/ml/input/data/train/train.csv
# SM_HP_VALIDATION_FILE=/opt/ml/input/data/val/val.csv
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages:/opt/conda/lib/python3.8/site-packages/smdebug-1.0.13b20220304-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument-3.4.2-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument_cext-0.2.4-py3.8-linux-x86_64.egg:/opt/conda/lib/python3.8/site-packages/urllib3-1.26.8-py3.8.egg
# Invoking script with the following command:
# /opt/conda/bin/python3.8 run_glue.py --do_train True --learning_rate 2e-05 --max_seq_length 128 --model_name_or_path bert-base-chinese --num_train_epochs 5 --output_dir /opt/ml/model/bert_base_chinese --per_device_train_batch_size 24 --train_file /opt/ml/input/data/train/train.csv --validation_file /opt/ml/input/data/val/val.csv
# 05/12/2022 02:31:45 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 05/12/2022 02:31:45 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# bf16=False,
# bf16_full_eval=False,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=False,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.NO,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=2e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=-1,
# log_level=-1,
# log_level_replica=-1,
# log_on_each_node=True,
# logging_dir=/opt/ml/model/bert_base_chinese/runs/May12_02-31-45_algo-1,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# no_cuda=False,
# num_train_epochs=5.0,
# optim=OptimizerNames.ADAMW_HF,
# output_dir=/opt/ml/model/bert_base_chinese,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=24,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# remove_unused_columns=True,
# report_to=[],
# resume_from_checkpoint=None,
# run_name=/opt/ml/model/bert_base_chinese,
# save_on_each_node=False,
# save_steps=500,
# save_strategy=IntervalStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# sharded_ddp=[],
# skip_memory_metrics=True,
# tf32=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_legacy_prediction_loop=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# xpu_backend=None,
# )
# 05/12/2022 02:31:45 - INFO - __main__ - load a local file for train: /opt/ml/input/data/train/train.csv
# 05/12/2022 02:31:45 - INFO - __main__ - load a local file for validation: /opt/ml/input/data/val/val.csv
# 05/12/2022 02:31:45 - WARNING - datasets.builder - Using custom data configuration default-6e1b113450ad5963
# 05/12/2022 02:31:45 - INFO - datasets.builder - Generating dataset csv (/root/.cache/huggingface/datasets/csv/default-6e1b113450ad5963/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-6e1b113450ad5963/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519...
# 0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00, 8594.89it/s]
# 05/12/2022 02:31:45 - INFO - datasets.utils.download_manager - Downloading took 0.0 min
# 05/12/2022 02:31:45 - INFO - datasets.utils.download_manager - Checksum Computation took 0.0 min
# 0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00, 2178.29it/s]
# 05/12/2022 02:31:45 - INFO - datasets.utils.info_utils - Unable to verify checksums.
# 05/12/2022 02:31:45 - INFO - datasets.builder - Generating split train
# 05/12/2022 02:31:46 - INFO - datasets.builder - Generating split validation
# 05/12/2022 02:31:46 - INFO - datasets.utils.info_utils - Unable to verify splits sizes.
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-6e1b113450ad5963/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
# 0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00, 426.77it/s]
# [INFO|file_utils.py:2215] 2022-05-12 02:31:46,076 >> https://huggingface.co/bert-base-chinese/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpg2k1_bo7
# [INFO|file_utils.py:2215] 2022-05-12 02:31:46,076 >> https://huggingface.co/bert-base-chinese/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpg2k1_bo7
# Downloading:   0%|          | 0.00/624 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 624/624 [00:00<00:00, 816kB/s]
# [INFO|file_utils.py:2219] 2022-05-12 02:31:46,108 >> storing https://huggingface.co/bert-base-chinese/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/6cc404ca8136bc87bae0fb24f2259904943d776a6c5ddc26598bbdc319476f42.0f9bcd8314d841c06633e7b92b04509f1802c16796ee67b0f1177065739e24ae
# [INFO|file_utils.py:2227] 2022-05-12 02:31:46,108 >> creating metadata file for /root/.cache/huggingface/transformers/6cc404ca8136bc87bae0fb24f2259904943d776a6c5ddc26598bbdc319476f42.0f9bcd8314d841c06633e7b92b04509f1802c16796ee67b0f1177065739e24ae
# [INFO|file_utils.py:2219] 2022-05-12 02:31:46,108 >> storing https://huggingface.co/bert-base-chinese/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/6cc404ca8136bc87bae0fb24f2259904943d776a6c5ddc26598bbdc319476f42.0f9bcd8314d841c06633e7b92b04509f1802c16796ee67b0f1177065739e24ae
# [INFO|file_utils.py:2227] 2022-05-12 02:31:46,108 >> creating metadata file for /root/.cache/huggingface/transformers/6cc404ca8136bc87bae0fb24f2259904943d776a6c5ddc26598bbdc319476f42.0f9bcd8314d841c06633e7b92b04509f1802c16796ee67b0f1177065739e24ae
# [INFO|configuration_utils.py:648] 2022-05-12 02:31:46,108 >> loading configuration file https://huggingface.co/bert-base-chinese/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/6cc404ca8136bc87bae0fb24f2259904943d776a6c5ddc26598bbdc319476f42.0f9bcd8314d841c06633e7b92b04509f1802c16796ee67b0f1177065739e24ae
# [INFO|configuration_utils.py:648] 2022-05-12 02:31:46,108 >> loading configuration file https://huggingface.co/bert-base-chinese/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/6cc404ca8136bc87bae0fb24f2259904943d776a6c5ddc26598bbdc319476f42.0f9bcd8314d841c06633e7b92b04509f1802c16796ee67b0f1177065739e24ae
# [INFO|configuration_utils.py:684] 2022-05-12 02:31:46,109 >> Model config BertConfig {
#   "_name_or_path": "bert-base-chinese",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11",
#     "12": "LABEL_12",
#     "13": "LABEL_13",
#     "14": "LABEL_14",
#     "15": "LABEL_15",
#     "16": "LABEL_16",
#     "17": "LABEL_17",
#     "18": "LABEL_18"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_12": 12,
#     "LABEL_13": 13,
#     "LABEL_14": 14,
#     "LABEL_15": 15,
#     "LABEL_16": 16,
#     "LABEL_17": 17,
#     "LABEL_18": 18,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 21128
# }
# [INFO|configuration_utils.py:684] 2022-05-12 02:31:46,109 >> Model config BertConfig {
#   "_name_or_path": "bert-base-chinese",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11",
#     "12": "LABEL_12",
#     "13": "LABEL_13",
#     "14": "LABEL_14",
#     "15": "LABEL_15",
#     "16": "LABEL_16",
#     "17": "LABEL_17",
#     "18": "LABEL_18"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_12": 12,
#     "LABEL_13": 13,
#     "LABEL_14": 14,
#     "LABEL_15": 15,
#     "LABEL_16": 16,
#     "LABEL_17": 17,
#     "LABEL_18": 18,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 21128
# }
# [INFO|file_utils.py:2215] 2022-05-12 02:31:46,136 >> https://huggingface.co/bert-base-chinese/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpdz3unafx
# [INFO|file_utils.py:2215] 2022-05-12 02:31:46,136 >> https://huggingface.co/bert-base-chinese/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpdz3unafx
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 29.0/29.0 [00:00<00:00, 37.8kB/s]
# [INFO|file_utils.py:2219] 2022-05-12 02:31:46,170 >> storing https://huggingface.co/bert-base-chinese/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/2dc6085404c55008ba7fc09ab7483ef3f0a4ca2496ccee0cdbf51c2b5d529dff.ec5c189f89475aac7d8cbd243960a0655cfadc3d0474da8ff2ed0bf1699c2a5f
# [INFO|file_utils.py:2219] 2022-05-12 02:31:46,170 >> storing https://huggingface.co/bert-base-chinese/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/2dc6085404c55008ba7fc09ab7483ef3f0a4ca2496ccee0cdbf51c2b5d529dff.ec5c189f89475aac7d8cbd243960a0655cfadc3d0474da8ff2ed0bf1699c2a5f
# [INFO|file_utils.py:2227] 2022-05-12 02:31:46,170 >> creating metadata file for /root/.cache/huggingface/transformers/2dc6085404c55008ba7fc09ab7483ef3f0a4ca2496ccee0cdbf51c2b5d529dff.ec5c189f89475aac7d8cbd243960a0655cfadc3d0474da8ff2ed0bf1699c2a5f
# [INFO|file_utils.py:2227] 2022-05-12 02:31:46,170 >> creating metadata file for /root/.cache/huggingface/transformers/2dc6085404c55008ba7fc09ab7483ef3f0a4ca2496ccee0cdbf51c2b5d529dff.ec5c189f89475aac7d8cbd243960a0655cfadc3d0474da8ff2ed0bf1699c2a5f
# [INFO|configuration_utils.py:648] 2022-05-12 02:31:46,198 >> loading configuration file https://huggingface.co/bert-base-chinese/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/6cc404ca8136bc87bae0fb24f2259904943d776a6c5ddc26598bbdc319476f42.0f9bcd8314d841c06633e7b92b04509f1802c16796ee67b0f1177065739e24ae
# [INFO|configuration_utils.py:648] 2022-05-12 02:31:46,198 >> loading configuration file https://huggingface.co/bert-base-chinese/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/6cc404ca8136bc87bae0fb24f2259904943d776a6c5ddc26598bbdc319476f42.0f9bcd8314d841c06633e7b92b04509f1802c16796ee67b0f1177065739e24ae
# [INFO|configuration_utils.py:684] 2022-05-12 02:31:46,199 >> Model config BertConfig {
#   "_name_or_path": "bert-base-chinese",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 21128
# }
# [INFO|configuration_utils.py:684] 2022-05-12 02:31:46,199 >> Model config BertConfig {
#   "_name_or_path": "bert-base-chinese",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 21128
# }
# [INFO|file_utils.py:2215] 2022-05-12 02:31:46,259 >> https://huggingface.co/bert-base-chinese/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmph2t2zwkb
# [INFO|file_utils.py:2215] 2022-05-12 02:31:46,259 >> https://huggingface.co/bert-base-chinese/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmph2t2zwkb
# Downloading:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 107k/107k [00:00<00:00, 47.1MB/s]
# [INFO|file_utils.py:2219] 2022-05-12 02:31:46,292 >> storing https://huggingface.co/bert-base-chinese/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/36acdf4f3edf0a14ffb2b2c68ba47e93abd9448825202377ddb16dae8114fe07.accd894ff58c6ff7bd4f3072890776c14f4ea34fcc08e79cd88c2d157756dceb
# [INFO|file_utils.py:2219] 2022-05-12 02:31:46,292 >> storing https://huggingface.co/bert-base-chinese/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/36acdf4f3edf0a14ffb2b2c68ba47e93abd9448825202377ddb16dae8114fe07.accd894ff58c6ff7bd4f3072890776c14f4ea34fcc08e79cd88c2d157756dceb
# [INFO|file_utils.py:2227] 2022-05-12 02:31:46,293 >> creating metadata file for /root/.cache/huggingface/transformers/36acdf4f3edf0a14ffb2b2c68ba47e93abd9448825202377ddb16dae8114fe07.accd894ff58c6ff7bd4f3072890776c14f4ea34fcc08e79cd88c2d157756dceb
# [INFO|file_utils.py:2227] 2022-05-12 02:31:46,293 >> creating metadata file for /root/.cache/huggingface/transformers/36acdf4f3edf0a14ffb2b2c68ba47e93abd9448825202377ddb16dae8114fe07.accd894ff58c6ff7bd4f3072890776c14f4ea34fcc08e79cd88c2d157756dceb
# [INFO|file_utils.py:2215] 2022-05-12 02:31:46,325 >> https://huggingface.co/bert-base-chinese/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpdclyasxz
# [INFO|file_utils.py:2215] 2022-05-12 02:31:46,325 >> https://huggingface.co/bert-base-chinese/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpdclyasxz
# Downloading:   0%|          | 0.00/263k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 263k/263k [00:00<00:00, 50.7MB/s]
# [INFO|file_utils.py:2219] 2022-05-12 02:31:46,366 >> storing https://huggingface.co/bert-base-chinese/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/7e23f4e1f58f867d672f84d9a459826e41cea3be6d0fe62502ddce9920f57e48.4495f7812b44ff0568ce7c4ff3fdbb2bac5eaf330440ffa30f46893bf749184d
# [INFO|file_utils.py:2219] 2022-05-12 02:31:46,366 >> storing https://huggingface.co/bert-base-chinese/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/7e23f4e1f58f867d672f84d9a459826e41cea3be6d0fe62502ddce9920f57e48.4495f7812b44ff0568ce7c4ff3fdbb2bac5eaf330440ffa30f46893bf749184d
# [INFO|file_utils.py:2227] 2022-05-12 02:31:46,366 >> creating metadata file for /root/.cache/huggingface/transformers/7e23f4e1f58f867d672f84d9a459826e41cea3be6d0fe62502ddce9920f57e48.4495f7812b44ff0568ce7c4ff3fdbb2bac5eaf330440ffa30f46893bf749184d
# [INFO|file_utils.py:2227] 2022-05-12 02:31:46,366 >> creating metadata file for /root/.cache/huggingface/transformers/7e23f4e1f58f867d672f84d9a459826e41cea3be6d0fe62502ddce9920f57e48.4495f7812b44ff0568ce7c4ff3fdbb2bac5eaf330440ffa30f46893bf749184d
# [INFO|tokenization_utils_base.py:1786] 2022-05-12 02:31:46,450 >> loading file https://huggingface.co/bert-base-chinese/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/36acdf4f3edf0a14ffb2b2c68ba47e93abd9448825202377ddb16dae8114fe07.accd894ff58c6ff7bd4f3072890776c14f4ea34fcc08e79cd88c2d157756dceb
# [INFO|tokenization_utils_base.py:1786] 2022-05-12 02:31:46,450 >> loading file https://huggingface.co/bert-base-chinese/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/7e23f4e1f58f867d672f84d9a459826e41cea3be6d0fe62502ddce9920f57e48.4495f7812b44ff0568ce7c4ff3fdbb2bac5eaf330440ffa30f46893bf749184d
# [INFO|tokenization_utils_base.py:1786] 2022-05-12 02:31:46,450 >> loading file https://huggingface.co/bert-base-chinese/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/36acdf4f3edf0a14ffb2b2c68ba47e93abd9448825202377ddb16dae8114fe07.accd894ff58c6ff7bd4f3072890776c14f4ea34fcc08e79cd88c2d157756dceb
# [INFO|tokenization_utils_base.py:1786] 2022-05-12 02:31:46,450 >> loading file https://huggingface.co/bert-base-chinese/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/7e23f4e1f58f867d672f84d9a459826e41cea3be6d0fe62502ddce9920f57e48.4495f7812b44ff0568ce7c4ff3fdbb2bac5eaf330440ffa30f46893bf749184d
# [INFO|tokenization_utils_base.py:1786] 2022-05-12 02:31:46,450 >> loading file https://huggingface.co/bert-base-chinese/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1786] 2022-05-12 02:31:46,450 >> loading file https://huggingface.co/bert-base-chinese/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1786] 2022-05-12 02:31:46,450 >> loading file https://huggingface.co/bert-base-chinese/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/2dc6085404c55008ba7fc09ab7483ef3f0a4ca2496ccee0cdbf51c2b5d529dff.ec5c189f89475aac7d8cbd243960a0655cfadc3d0474da8ff2ed0bf1699c2a5f
# [INFO|tokenization_utils_base.py:1786] 2022-05-12 02:31:46,450 >> loading file https://huggingface.co/bert-base-chinese/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1786] 2022-05-12 02:31:46,450 >> loading file https://huggingface.co/bert-base-chinese/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1786] 2022-05-12 02:31:46,450 >> loading file https://huggingface.co/bert-base-chinese/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/2dc6085404c55008ba7fc09ab7483ef3f0a4ca2496ccee0cdbf51c2b5d529dff.ec5c189f89475aac7d8cbd243960a0655cfadc3d0474da8ff2ed0bf1699c2a5f
# [INFO|configuration_utils.py:648] 2022-05-12 02:31:46,476 >> loading configuration file https://huggingface.co/bert-base-chinese/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/6cc404ca8136bc87bae0fb24f2259904943d776a6c5ddc26598bbdc319476f42.0f9bcd8314d841c06633e7b92b04509f1802c16796ee67b0f1177065739e24ae
# [INFO|configuration_utils.py:648] 2022-05-12 02:31:46,476 >> loading configuration file https://huggingface.co/bert-base-chinese/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/6cc404ca8136bc87bae0fb24f2259904943d776a6c5ddc26598bbdc319476f42.0f9bcd8314d841c06633e7b92b04509f1802c16796ee67b0f1177065739e24ae
# [INFO|configuration_utils.py:684] 2022-05-12 02:31:46,477 >> Model config BertConfig {
#   "_name_or_path": "bert-base-chinese",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 21128
# }
# [INFO|configuration_utils.py:684] 2022-05-12 02:31:46,477 >> Model config BertConfig {
#   "_name_or_path": "bert-base-chinese",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 21128
# }
# [INFO|file_utils.py:2215] 2022-05-12 02:31:46,557 >> https://huggingface.co/bert-base-chinese/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpicx472mp
# [INFO|file_utils.py:2215] 2022-05-12 02:31:46,557 >> https://huggingface.co/bert-base-chinese/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpicx472mp
# Downloading:   0%|          | 0.00/393M [00:00<?, ?B/s]
# Downloading:   2%|▏         | 7.04M/393M [00:00<00:05, 73.8MB/s]
# Downloading:   4%|▍         | 14.8M/393M [00:00<00:05, 78.3MB/s]
# Downloading:   6%|▌         | 22.3M/393M [00:00<00:05, 77.3MB/s]
# Downloading:   8%|▊         | 29.6M/393M [00:00<00:04, 77.0MB/s]
# Downloading:  10%|▉         | 38.6M/393M [00:00<00:04, 82.9MB/s]
# Downloading:  12%|█▏        | 46.6M/393M [00:00<00:04, 83.4MB/s]
# Downloading:  14%|█▍        | 54.6M/393M [00:00<00:04, 82.1MB/s]
# Downloading:  16%|█▋        | 64.1M/393M [00:00<00:03, 87.6MB/s]
# Downloading:  19%|█▊        | 73.0M/393M [00:00<00:03, 89.4MB/s]
# Downloading:  21%|██        | 81.5M/393M [00:01<00:03, 89.5MB/s]
# Downloading:  23%|██▎       | 90.3M/393M [00:01<00:03, 90.1MB/s]
# Downloading:  25%|██▌       | 98.9M/393M [00:01<00:03, 88.3MB/s]
# Downloading:  27%|██▋       | 107M/393M [00:01<00:04, 71.2MB/s]
# Downloading:  30%|██▉       | 116M/393M [00:01<00:03, 76.4MB/s]
# Downloading:  32%|███▏      | 125M/393M [00:01<00:03, 81.4MB/s]
# Downloading:  34%|███▍      | 134M/393M [00:01<00:03, 84.1MB/s]
# Downloading:  36%|███▌      | 142M/393M [00:01<00:03, 85.2MB/s]
# Downloading:  39%|███▊      | 152M/393M [00:01<00:02, 89.4MB/s]
# Downloading:  41%|████      | 160M/393M [00:01<00:02, 89.5MB/s]
# Downloading:  43%|████▎     | 169M/393M [00:02<00:02, 90.0MB/s]
# Downloading:  45%|████▌     | 178M/393M [00:02<00:02, 86.5MB/s]
# Downloading:  48%|████▊     | 187M/393M [00:02<00:02, 89.9MB/s]
# Downloading:  50%|████▉     | 196M/393M [00:02<00:02, 90.7MB/s]
# Downloading:  52%|█████▏    | 205M/393M [00:02<00:02, 91.0MB/s]
# Downloading:  54%|█████▍    | 214M/393M [00:02<00:02, 91.9MB/s]
# Downloading:  57%|█████▋    | 223M/393M [00:02<00:01, 89.3MB/s]
# Downloading:  59%|█████▉    | 231M/393M [00:02<00:01, 90.6MB/s]
# Downloading:  61%|██████    | 240M/393M [00:02<00:01, 88.6MB/s]
# Downloading:  63%|██████▎   | 249M/393M [00:03<00:01, 89.6MB/s]
# Downloading:  66%|██████▌   | 258M/393M [00:03<00:01, 90.1MB/s]
# Downloading:  68%|██████▊   | 267M/393M [00:03<00:01, 93.8MB/s]
# Downloading:  71%|███████   | 277M/393M [00:03<00:01, 95.0MB/s]
# Downloading:  73%|███████▎  | 286M/393M [00:03<00:01, 93.3MB/s]
# Downloading:  75%|███████▌  | 295M/393M [00:03<00:01, 95.6MB/s]
# Downloading:  78%|███████▊  | 305M/393M [00:03<00:00, 94.2MB/s]
# Downloading:  80%|███████▉  | 314M/393M [00:03<00:00, 95.3MB/s]
# Downloading:  82%|████████▏ | 323M/393M [00:03<00:00, 92.5MB/s]
# Downloading:  85%|████████▍ | 332M/393M [00:03<00:00, 92.9MB/s]
# Downloading:  87%|████████▋ | 341M/393M [00:04<00:00, 92.2MB/s]
# Downloading:  89%|████████▉ | 350M/393M [00:04<00:00, 88.9MB/s]
# Downloading:  91%|█████████▏| 359M/393M [00:04<00:00, 90.2MB/s]
# Downloading:  94%|█████████▎| 367M/393M [00:04<00:00, 89.3MB/s]
# Downloading:  96%|█████████▌| 376M/393M [00:04<00:00, 89.6MB/s]
# Downloading:  98%|█████████▊| 384M/393M [00:04<00:00, 89.9MB/s]
# Downloading: 100%|██████████| 393M/393M [00:04<00:00, 88.1MB/s]
# [INFO|file_utils.py:2219] 2022-05-12 02:31:51,247 >> storing https://huggingface.co/bert-base-chinese/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/58592490276d9ed1e8e33f3c12caf23000c22973cb2b3218c641bd74547a1889.fabda197bfe5d6a318c2833172d6757ccc7e49f692cb949a6fabf560cee81508
# [INFO|file_utils.py:2227] 2022-05-12 02:31:51,247 >> creating metadata file for /root/.cache/huggingface/transformers/58592490276d9ed1e8e33f3c12caf23000c22973cb2b3218c641bd74547a1889.fabda197bfe5d6a318c2833172d6757ccc7e49f692cb949a6fabf560cee81508
# [INFO|modeling_utils.py:1431] 2022-05-12 02:31:51,247 >> loading weights file https://huggingface.co/bert-base-chinese/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/58592490276d9ed1e8e33f3c12caf23000c22973cb2b3218c641bd74547a1889.fabda197bfe5d6a318c2833172d6757ccc7e49f692cb949a6fabf560cee81508
# [INFO|file_utils.py:2219] 2022-05-12 02:31:51,247 >> storing https://huggingface.co/bert-base-chinese/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/58592490276d9ed1e8e33f3c12caf23000c22973cb2b3218c641bd74547a1889.fabda197bfe5d6a318c2833172d6757ccc7e49f692cb949a6fabf560cee81508
# [INFO|file_utils.py:2227] 2022-05-12 02:31:51,247 >> creating metadata file for /root/.cache/huggingface/transformers/58592490276d9ed1e8e33f3c12caf23000c22973cb2b3218c641bd74547a1889.fabda197bfe5d6a318c2833172d6757ccc7e49f692cb949a6fabf560cee81508
# [INFO|modeling_utils.py:1431] 2022-05-12 02:31:51,247 >> loading weights file https://huggingface.co/bert-base-chinese/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/58592490276d9ed1e8e33f3c12caf23000c22973cb2b3218c641bd74547a1889.fabda197bfe5d6a318c2833172d6757ccc7e49f692cb949a6fabf560cee81508
# [WARNING|modeling_utils.py:1693] 2022-05-12 02:31:52,331 >> Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:1704] 2022-05-12 02:31:52,331 >> Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-chinese and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [WARNING|modeling_utils.py:1693] 2022-05-12 02:31:52,331 >> Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:1704] 2022-05-12 02:31:52,331 >> Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-chinese and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Running tokenizer on dataset:   0%|          | 0/243 [00:00<?, ?ba/s]
# 05/12/2022 02:31:52 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/csv/default-6e1b113450ad5963/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-200a1cb71febc2d4.arrow
# Running tokenizer on dataset:   0%|          | 1/243 [00:00<00:34,  7.11ba/s]
# Running tokenizer on dataset:   1%|          | 3/243 [00:00<00:23, 10.28ba/s]
# Running tokenizer on dataset:   2%|▏         | 5/243 [00:00<00:17, 13.49ba/s]
# Running tokenizer on dataset:   3%|▎         | 7/243 [00:00<00:15, 15.01ba/s]
# Running tokenizer on dataset:   4%|▎         | 9/243 [00:00<00:14, 15.97ba/s]
# Running tokenizer on dataset:   5%|▍         | 11/243 [00:00<00:14, 16.37ba/s]
# Running tokenizer on dataset:   5%|▌         | 13/243 [00:00<00:13, 17.23ba/s]
# Running tokenizer on dataset:   6%|▌         | 15/243 [00:01<00:15, 14.68ba/s]
# Running tokenizer on dataset:   7%|▋         | 17/243 [00:01<00:14, 15.47ba/s]
# Running tokenizer on dataset:   8%|▊         | 19/243 [00:01<00:13, 16.23ba/s]
# Running tokenizer on dataset:   9%|▊         | 21/243 [00:01<00:14, 15.49ba/s]
# Running tokenizer on dataset:   9%|▉         | 23/243 [00:01<00:13, 16.44ba/s]
# Running tokenizer on dataset:  11%|█         | 26/243 [00:01<00:12, 17.57ba/s]
# Running tokenizer on dataset:  12%|█▏        | 28/243 [00:01<00:13, 15.55ba/s]
# Running tokenizer on dataset:  12%|█▏        | 30/243 [00:01<00:13, 15.91ba/s]
# Running tokenizer on dataset:  13%|█▎        | 32/243 [00:02<00:13, 16.08ba/s]
# Running tokenizer on dataset:  14%|█▍        | 34/243 [00:02<00:12, 16.66ba/s]
# Running tokenizer on dataset:  15%|█▍        | 36/243 [00:02<00:11, 17.33ba/s]
# Running tokenizer on dataset:  16%|█▌        | 38/243 [00:02<00:11, 17.67ba/s]
# Running tokenizer on dataset:  16%|█▋        | 40/243 [00:02<00:13, 15.00ba/s]
# Running tokenizer on dataset:  17%|█▋        | 42/243 [00:02<00:12, 15.82ba/s]
# Running tokenizer on dataset:  18%|█▊        | 44/243 [00:02<00:11, 16.79ba/s]
# Running tokenizer on dataset:  19%|█▉        | 46/243 [00:02<00:11, 17.36ba/s]
# Running tokenizer on dataset:  20%|█▉        | 48/243 [00:02<00:10, 17.85ba/s]
# Running tokenizer on dataset:  21%|██        | 51/243 [00:03<00:11, 16.12ba/s]
# Running tokenizer on dataset:  22%|██▏       | 53/243 [00:03<00:11, 16.85ba/s]
# Running tokenizer on dataset:  23%|██▎       | 55/243 [00:03<00:10, 17.29ba/s]
# Running tokenizer on dataset:  23%|██▎       | 57/243 [00:03<00:10, 17.30ba/s]
# Running tokenizer on dataset:  24%|██▍       | 59/243 [00:03<00:10, 17.65ba/s]
# Running tokenizer on dataset:  25%|██▌       | 61/243 [00:03<00:10, 17.89ba/s]
# Running tokenizer on dataset:  26%|██▌       | 63/243 [00:03<00:11, 15.74ba/s]
# Running tokenizer on dataset:  27%|██▋       | 65/243 [00:04<00:10, 16.26ba/s]
# Running tokenizer on dataset:  28%|██▊       | 67/243 [00:04<00:10, 17.13ba/s]
# Running tokenizer on dataset:  28%|██▊       | 69/243 [00:04<00:09, 17.74ba/s]
# Running tokenizer on dataset:  29%|██▉       | 71/243 [00:04<00:09, 18.32ba/s]
# Running tokenizer on dataset:  30%|███       | 73/243 [00:04<00:09, 18.47ba/s]
# Running tokenizer on dataset:  31%|███       | 75/243 [00:04<00:10, 15.56ba/s]
# Running tokenizer on dataset:  32%|███▏      | 77/243 [00:04<00:10, 16.43ba/s]
# Running tokenizer on dataset:  33%|███▎      | 79/243 [00:04<00:09, 16.68ba/s]
# Running tokenizer on dataset:  33%|███▎      | 81/243 [00:04<00:09, 17.35ba/s]
# Running tokenizer on dataset:  34%|███▍      | 83/243 [00:05<00:09, 17.73ba/s]
# Running tokenizer on dataset:  35%|███▍      | 85/243 [00:05<00:08, 17.98ba/s]
# Running tokenizer on dataset:  36%|███▌      | 87/243 [00:05<00:10, 15.48ba/s]
# Running tokenizer on dataset:  37%|███▋      | 89/243 [00:05<00:09, 16.24ba/s]
# Running tokenizer on dataset:  37%|███▋      | 91/243 [00:05<00:09, 16.18ba/s]
# Running tokenizer on dataset:  38%|███▊      | 93/243 [00:05<00:08, 16.89ba/s]
# Running tokenizer on dataset:  39%|███▉      | 95/243 [00:05<00:08, 17.54ba/s]
# Running tokenizer on dataset:  40%|███▉      | 97/243 [00:05<00:08, 17.58ba/s]
# Running tokenizer on dataset:  41%|████      | 99/243 [00:06<00:09, 15.48ba/s]
# Running tokenizer on dataset:  42%|████▏     | 101/243 [00:06<00:08, 16.21ba/s]
# Running tokenizer on dataset:  42%|████▏     | 103/243 [00:06<00:08, 16.95ba/s]
# Running tokenizer on dataset:  43%|████▎     | 105/243 [00:06<00:08, 17.24ba/s]
# Running tokenizer on dataset:  44%|████▍     | 108/243 [00:06<00:07, 18.18ba/s]
# Running tokenizer on dataset:  45%|████▌     | 110/243 [00:06<00:07, 18.58ba/s]
# Running tokenizer on dataset:  46%|████▌     | 112/243 [00:06<00:08, 15.98ba/s]
# Running tokenizer on dataset:  47%|████▋     | 114/243 [00:06<00:07, 16.46ba/s]
# Running tokenizer on dataset:  48%|████▊     | 116/243 [00:07<00:07, 17.03ba/s]
# Running tokenizer on dataset:  49%|████▊     | 118/243 [00:07<00:07, 17.30ba/s]
# Running tokenizer on dataset:  49%|████▉     | 120/243 [00:07<00:07, 17.46ba/s]
# Running tokenizer on dataset:  50%|█████     | 122/243 [00:07<00:07, 17.06ba/s]
# Running tokenizer on dataset:  51%|█████     | 124/243 [00:07<00:07, 15.05ba/s]
# Running tokenizer on dataset:  52%|█████▏    | 126/243 [00:07<00:07, 15.91ba/s]
# Running tokenizer on dataset:  53%|█████▎    | 128/243 [00:07<00:06, 16.50ba/s]
# Running tokenizer on dataset:  53%|█████▎    | 130/243 [00:07<00:06, 16.92ba/s]
# Running tokenizer on dataset:  54%|█████▍    | 132/243 [00:07<00:06, 17.59ba/s]
# Running tokenizer on dataset:  55%|█████▌    | 134/243 [00:08<00:06, 17.35ba/s]
# Running tokenizer on dataset:  56%|█████▌    | 136/243 [00:08<00:06, 15.57ba/s]
# Running tokenizer on dataset:  57%|█████▋    | 138/243 [00:08<00:06, 16.66ba/s]
# Running tokenizer on dataset:  58%|█████▊    | 140/243 [00:08<00:05, 17.28ba/s]
# Running tokenizer on dataset:  58%|█████▊    | 142/243 [00:08<00:05, 17.69ba/s]
# Running tokenizer on dataset:  59%|█████▉    | 144/243 [00:08<00:05, 18.25ba/s]
# Running tokenizer on dataset:  60%|██████    | 146/243 [00:08<00:05, 17.95ba/s]
# Running tokenizer on dataset:  61%|██████    | 148/243 [00:08<00:06, 15.70ba/s]
# Running tokenizer on dataset:  62%|██████▏   | 150/243 [00:09<00:05, 16.59ba/s]
# Running tokenizer on dataset:  63%|██████▎   | 152/243 [00:09<00:05, 17.34ba/s]
# Running tokenizer on dataset:  63%|██████▎   | 154/243 [00:09<00:05, 17.53ba/s]
# Running tokenizer on dataset:  64%|██████▍   | 156/243 [00:09<00:04, 17.46ba/s]
# Running tokenizer on dataset:  65%|██████▌   | 158/243 [00:09<00:05, 15.39ba/s]
# Running tokenizer on dataset:  66%|██████▌   | 160/243 [00:09<00:06, 13.08ba/s]
# Running tokenizer on dataset:  67%|██████▋   | 162/243 [00:09<00:05, 14.43ba/s]
# Running tokenizer on dataset:  67%|██████▋   | 164/243 [00:09<00:05, 15.37ba/s]
# Running tokenizer on dataset:  68%|██████▊   | 166/243 [00:10<00:04, 16.37ba/s]
# Running tokenizer on dataset:  69%|██████▉   | 168/243 [00:10<00:04, 17.07ba/s]
# Running tokenizer on dataset:  70%|██████▉   | 170/243 [00:10<00:04, 17.24ba/s]
# Running tokenizer on dataset:  71%|███████   | 172/243 [00:10<00:04, 14.79ba/s]
# Running tokenizer on dataset:  72%|███████▏  | 174/243 [00:10<00:04, 15.10ba/s]
# Running tokenizer on dataset:  72%|███████▏  | 176/243 [00:10<00:04, 15.17ba/s]
# Running tokenizer on dataset:  73%|███████▎  | 178/243 [00:10<00:04, 15.29ba/s]
# Running tokenizer on dataset:  74%|███████▍  | 180/243 [00:10<00:04, 15.46ba/s]
# Running tokenizer on dataset:  75%|███████▍  | 182/243 [00:11<00:03, 15.89ba/s]
# Running tokenizer on dataset:  76%|███████▌  | 184/243 [00:11<00:04, 14.25ba/s]
# Running tokenizer on dataset:  77%|███████▋  | 186/243 [00:11<00:03, 15.34ba/s]
# Running tokenizer on dataset:  77%|███████▋  | 188/243 [00:11<00:03, 16.02ba/s]
# Running tokenizer on dataset:  78%|███████▊  | 190/243 [00:11<00:03, 16.82ba/s]
# Running tokenizer on dataset:  79%|███████▉  | 192/243 [00:11<00:03, 16.20ba/s]
# Running tokenizer on dataset:  80%|███████▉  | 194/243 [00:11<00:03, 15.51ba/s]
# Running tokenizer on dataset:  81%|████████  | 196/243 [00:12<00:03, 13.41ba/s]
# Running tokenizer on dataset:  81%|████████▏ | 198/243 [00:12<00:03, 13.70ba/s]
# Running tokenizer on dataset:  82%|████████▏ | 200/243 [00:12<00:03, 14.33ba/s]
# Running tokenizer on dataset:  83%|████████▎ | 202/243 [00:12<00:02, 14.71ba/s]
# Running tokenizer on dataset:  84%|████████▍ | 204/243 [00:12<00:02, 14.80ba/s]
# Running tokenizer on dataset:  85%|████████▍ | 206/243 [00:12<00:02, 15.55ba/s]
# Running tokenizer on dataset:  86%|████████▌ | 208/243 [00:12<00:02, 14.25ba/s]
# Running tokenizer on dataset:  86%|████████▋ | 210/243 [00:12<00:02, 15.27ba/s]
# Running tokenizer on dataset:  87%|████████▋ | 212/243 [00:13<00:01, 15.66ba/s]
# Running tokenizer on dataset:  88%|████████▊ | 214/243 [00:13<00:01, 16.54ba/s]
# Running tokenizer on dataset:  89%|████████▉ | 216/243 [00:13<00:01, 17.33ba/s]
# Running tokenizer on dataset:  90%|████████▉ | 218/243 [00:13<00:01, 17.49ba/s]
# Running tokenizer on dataset:  91%|█████████ | 220/243 [00:13<00:01, 15.18ba/s]
# Running tokenizer on dataset:  91%|█████████▏| 222/243 [00:13<00:01, 15.86ba/s]
# Running tokenizer on dataset:  92%|█████████▏| 224/243 [00:13<00:01, 16.42ba/s]
# Running tokenizer on dataset:  93%|█████████▎| 226/243 [00:13<00:01, 16.68ba/s]
# Running tokenizer on dataset:  94%|█████████▍| 228/243 [00:14<00:00, 17.35ba/s]
# ...
# 51%|█████     | 25625/50610 [1:01:32<58:23,  7.13it/s]
# 51%|█████     | 25626/50610 [1:01:32<58:19,  7.14it/s]
# 51%|█████     | 25627/50610 [1:01:32<58:39,  7.10it/s]
# 51%|█████     | 25628/50610 [1:01:32<58:34,  7.11it/s]
# 51%|█████     | 25629/50610 [1:01:32<58:53,  7.07it/s]
# 51%|█████     | 25630/50610 [1:01:32<58:53,  7.07it/s]
# 51%|█████     | 25631/50610 [1:01:32<58:34,  7.11it/s]
# 51%|█████     | 25632/50610 [1:01:33<58:29,  7.12it/s]
# 51%|█████     | 25633/50610 [1:01:33<58:12,  7.15it/s]
# 51%|█████     | 25634/50610 [1:01:33<58:17,  7.14it/s]
# 51%|█████     | 25635/50610 [1:01:33<58:21,  7.13it/s]
# 51%|█████     | 25890/50610 [1:02:09<57:38,  7.15it/s]
# 51%|█████     | 25891/50610 [1:02:09<57:35,  7.15it/s]
# 51%|█████     | 25892/50610 [1:02:09<57:57,  7.11it/s]
# 51%|█████     | 25893/50610 [1:02:09<57:38,  7.15it/s]
# 51%|█████     | 25894/50610 [1:02:10<57:32,  7.16it/s]
# 51%|█████     | 25895/50610 [1:02:10<57:35,  7.15it/s]
# 51%|█████     | 25896/50610 [1:02:10<57:39,  7.14it/s]
# 51%|█████     | 25897/50610 [1:02:10<57:33,  7.16it/s]
# 51%|█████     | 25898/50610 [1:02:10<57:50,  7.12it/s]
# 51%|█████     | 25899/50610 [1:02:10<57:37,  7.15it/s]
# 51%|█████     | 25900/50610 [1:02:10<57:49,  7.12it/s]
# 51%|█████     | 25901/50610 [1:02:11<57:55,  7.11it/s]
# 51%|█████     | 25902/50610 [1:02:11<58:02,  7.10it/s]
# 51%|█████     | 25903/50610 [1:02:11<58:01,  7.10it/s]
# 51%|█████     | 25904/50610 [1:02:11<57:58,  7.10it/s]
# 51%|█████     | 25905/50610 [1:02:11<57:49,  7.12it/s]
# 51%|█████     | 25906/50610 [1:02:11<58:29,  7.04it/s]
# 51%|█████     | 25907/50610 [1:02:11<58:34,  7.03it/s]
# 51%|█████     | 25908/50610 [1:02:12<58:04,  7.09it/s]
# 51%|█████     | 25909/50610 [1:02:12<57:51,  7.12it/s]
# 51%|█████     | 25910/50610 [1:02:12<57:39,  7.14it/s]
# 51%|█████     | 25911/50610 [1:02:12<57:41,  7.13it/s]
# 51%|█████     | 25912/50610 [1:02:12<57:38,  7.14it/s]
# 51%|█████     | 25913/50610 [1:02:12<57:47,  7.12it/s]
# 51%|█████     | 25914/50610 [1:02:12<58:19,  7.06it/s]

# %%
#attach back to trainning job if needed:
import sagemaker
import boto3

need_attach = False
session = sagemaker.Session()
if need_attach:
    output = sagemaker.estimator.Estimator.attach('huggingface-pytorch-training-2022-05-12-02-25-20-722', sagemaker_session = session)
    print(output)

# %% [markdown]
# # Eval

# %%
import transformers
from sagemaker.huggingface import HuggingFace
from sagemaker.huggingface.model import HuggingFaceModel

import_from_s3 = False

if import_from_s3:
    #To restore old trainning job
    # create Hugging Face Model Class
    huggingface_model = HuggingFaceModel(
        model_data="s3://sagemaker-us-east-1-635837196364/huggingface-pytorch-training-2022-05-12-00-16-12-039/output/model.tar.gz",  # path to your trained SageMaker model
        role=role,                                            # IAM role with permissions to create an endpoint
        transformers_version='4.17.0',                        # Transformers version used
        pytorch_version='1.10.2',                             # PyTorch version used
        py_version='py38',                                # Python version used
        env = {
            'HF_MODEL_ID':'uer/chinese_roberta_L-12_H-768',
            'HF_TASK': 'text-classification',

        },
    )
    # deploy model to SageMaker Inference
    predictor = huggingface_model.deploy(
       initial_instance_count=1,
       instance_type="ml.m5.4xlarge"
    )
else:
    predictor = huggingface_estimator.deploy(1, "ml.m5.4xlarge")

# %%
input = ["input": '你好呀']

predictor.predict(input)

# %%
#predictor.delete_endpoint()
