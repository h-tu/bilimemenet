# %%
import argparse
from T5Finetunner import T5FineTuner, LoggingCallback
import glob
import random
import shutil
from transformers import T5ForConditionalGeneration, T5Tokenizer, AdamW, get_linear_schedule_with_warmup
import torch
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl
from T5Finetunner import ImdbDataset 
from DanMuDataset import DanMuDataset

data_path = "/media/zihao/New Volume1/UMASS/685_e/github/Zihao_branch/data/Danmu_byt5/pkl"

# %%
args_dict = dict(
    data_dir= data_path, # path for data files
    output_dir="checkpoints", # path to save the checkpoints
    #model_name_or_path='t5-base',
    model_name_or_path = 'google/byt5-small',
    tokenizer_name_or_path='google/byt5-small',
    max_seq_length=512,
    learning_rate=3e-4,
    weight_decay=0.0,
    adam_epsilon=1e-8,
    warmup_steps=0,
    train_batch_size=1,
    eval_batch_size=1,
    num_train_epochs=2,
    gradient_accumulation_steps=16,
    n_gpu=1,
    early_stop_callback=False,
    fp_16=False, # if you want to enable 16-bit training then install apex and set this to true
    opt_level='O1', # you can find out more on optimisation levels here https://nvidia.github.io/apex/amp.html#opt-levels-and-properties
    max_grad_norm=1.0, # if you enable 16-bit training then set this to a sensible value, 0.5 is a good default
    seed=42,
)

# %%
train_pos_files = glob.glob( data_path +'/train/pos/*.txt')
train_neg_files = glob.glob( data_path +'/train/neg/*.txt')

random.shuffle(train_pos_files)
random.shuffle(train_neg_files)

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
dataset = DanMuDataset(tokenizer, data_path, 'val',  max_len=512)
print('dataset:')
print(len(dataset))
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/zihao/anaconda3/envs/py37/lib/python3.7/site-packages/transformers/tokenization_utils_base.py:2217: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /home/zihao/anaconda3/envs/py37/lib/python3.7/site-packages/transformers/models/t5/tokenization_t5.py:191: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   f"This sequence already has {self.eos_token}. In future versions this behavior may lead to duplicated eos tokens being added."
# dataset:
# 33740

# %%
args_dict.update({'output_dir': 't5_imdb_sentiment', 'num_train_epochs':2})
args = argparse.Namespace(**args_dict)

checkpoint_callback = pl.callbacks.ModelCheckpoint(
    filepath=args.output_dir, prefix="checkpoint", monitor="val_loss", mode="min", save_top_k=5
)
# Out:
# /home/zihao/anaconda3/envs/py37/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:23: UserWarning: Checkpoint directory t5_imdb_sentiment exists and is not empty with save_top_k != 0.All files in this directory will be deleted when a checkpoint is saved!
#   warnings.warn(*args, **kwargs)

# %%
train_params = dict(
    accumulate_grad_batches=args.gradient_accumulation_steps,
    gpus=args.n_gpu,
    max_epochs=args.num_train_epochs,
    early_stop_callback=False,
    precision= 16 if args.fp_16 else 32,
    amp_level=args.opt_level,
    gradient_clip_val=args.max_grad_norm,
    checkpoint_callback=checkpoint_callback,
    callbacks=[LoggingCallback()],
)

# %%
def get_dataset(tokenizer, type_path, args):
    #return ImdbDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)
    return DanMuDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)

# %%
model = T5FineTuner(args)
#print(model.val_dataloader())

trainer = pl.Trainer(**train_params)
# Out:
# Downloading: 100%|██████████| 2.53k/2.53k [00:00<00:00, 596kB/s]
# Downloading: 100%|██████████| 2.44k/2.44k [00:00<00:00, 677kB/s]
# INFO:lightning:GPU available: True, used: True
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]

# %%
trainer.fit(model)
# Out:
# INFO:lightning:
#     | Name                                                                | Type                       | Params
# ---------------------------------------------------------------------------------------------------------------
# 0   | model                                                               | T5ForConditionalGeneration | 299 M
# 1   | model.shared                                                        | Embedding                  | 565 K
# 2   | model.encoder                                                       | T5Stack                    | 217 M
# 3   | model.encoder.block                                                 | ModuleList                 | 217 M
# 4   | model.encoder.block.0                                               | T5Block                    | 18 M
# 5   | model.encoder.block.0.layer                                         | ModuleList                 | 18 M
# 6   | model.encoder.block.0.layer.0                                       | T5LayerSelfAttention       | 2 M
# 7   | model.encoder.block.0.layer.0.SelfAttention                         | T5Attention                | 2 M
# 8   | model.encoder.block.0.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 9   | model.encoder.block.0.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 10  | model.encoder.block.0.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 11  | model.encoder.block.0.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 12  | model.encoder.block.0.layer.0.SelfAttention.relative_attention_bias | Embedding                  | 192
# 13  | model.encoder.block.0.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 14  | model.encoder.block.0.layer.0.dropout                               | Dropout                    | 0
# 15  | model.encoder.block.0.layer.1                                       | T5LayerFF                  | 15 M
# 16  | model.encoder.block.0.layer.1.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 17  | model.encoder.block.0.layer.1.DenseReluDense.wi_0                   | Linear                     | 5 M
# 18  | model.encoder.block.0.layer.1.DenseReluDense.wi_1                   | Linear                     | 5 M
# 19  | model.encoder.block.0.layer.1.DenseReluDense.wo                     | Linear                     | 5 M
# 20  | model.encoder.block.0.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 21  | model.encoder.block.0.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 22  | model.encoder.block.0.layer.1.dropout                               | Dropout                    | 0
# 23  | model.encoder.block.1                                               | T5Block                    | 18 M
# 24  | model.encoder.block.1.layer                                         | ModuleList                 | 18 M
# 25  | model.encoder.block.1.layer.0                                       | T5LayerSelfAttention       | 2 M
# 26  | model.encoder.block.1.layer.0.SelfAttention                         | T5Attention                | 2 M
# 27  | model.encoder.block.1.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 28  | model.encoder.block.1.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 29  | model.encoder.block.1.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 30  | model.encoder.block.1.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 31  | model.encoder.block.1.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 32  | model.encoder.block.1.layer.0.dropout                               | Dropout                    | 0
# 33  | model.encoder.block.1.layer.1                                       | T5LayerFF                  | 15 M
# 34  | model.encoder.block.1.layer.1.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 35  | model.encoder.block.1.layer.1.DenseReluDense.wi_0                   | Linear                     | 5 M
# 36  | model.encoder.block.1.layer.1.DenseReluDense.wi_1                   | Linear                     | 5 M
# 37  | model.encoder.block.1.layer.1.DenseReluDense.wo                     | Linear                     | 5 M
# 38  | model.encoder.block.1.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 39  | model.encoder.block.1.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 40  | model.encoder.block.1.layer.1.dropout                               | Dropout                    | 0
# 41  | model.encoder.block.2                                               | T5Block                    | 18 M
# 42  | model.encoder.block.2.layer                                         | ModuleList                 | 18 M
# 43  | model.encoder.block.2.layer.0                                       | T5LayerSelfAttention       | 2 M
# 44  | model.encoder.block.2.layer.0.SelfAttention                         | T5Attention                | 2 M
# 45  | model.encoder.block.2.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 46  | model.encoder.block.2.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 47  | model.encoder.block.2.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 48  | model.encoder.block.2.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 49  | model.encoder.block.2.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 50  | model.encoder.block.2.layer.0.dropout                               | Dropout                    | 0
# 51  | model.encoder.block.2.layer.1                                       | T5LayerFF                  | 15 M
# 52  | model.encoder.block.2.layer.1.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 53  | model.encoder.block.2.layer.1.DenseReluDense.wi_0                   | Linear                     | 5 M
# 54  | model.encoder.block.2.layer.1.DenseReluDense.wi_1                   | Linear                     | 5 M
# 55  | model.encoder.block.2.layer.1.DenseReluDense.wo                     | Linear                     | 5 M
# 56  | model.encoder.block.2.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 57  | model.encoder.block.2.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 58  | model.encoder.block.2.layer.1.dropout                               | Dropout                    | 0
# 59  | model.encoder.block.3                                               | T5Block                    | 18 M
# 60  | model.encoder.block.3.layer                                         | ModuleList                 | 18 M
# 61  | model.encoder.block.3.layer.0                                       | T5LayerSelfAttention       | 2 M
# 62  | model.encoder.block.3.layer.0.SelfAttention                         | T5Attention                | 2 M
# 63  | model.encoder.block.3.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 64  | model.encoder.block.3.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 65  | model.encoder.block.3.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 66  | model.encoder.block.3.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 67  | model.encoder.block.3.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 68  | model.encoder.block.3.layer.0.dropout                               | Dropout                    | 0
# 69  | model.encoder.block.3.layer.1                                       | T5LayerFF                  | 15 M
# 70  | model.encoder.block.3.layer.1.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 71  | model.encoder.block.3.layer.1.DenseReluDense.wi_0                   | Linear                     | 5 M
# 72  | model.encoder.block.3.layer.1.DenseReluDense.wi_1                   | Linear                     | 5 M
# 73  | model.encoder.block.3.layer.1.DenseReluDense.wo                     | Linear                     | 5 M
# 74  | model.encoder.block.3.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 75  | model.encoder.block.3.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 76  | model.encoder.block.3.layer.1.dropout                               | Dropout                    | 0
# 77  | model.encoder.block.4                                               | T5Block                    | 18 M
# 78  | model.encoder.block.4.layer                                         | ModuleList                 | 18 M
# 79  | model.encoder.block.4.layer.0                                       | T5LayerSelfAttention       | 2 M
# 80  | model.encoder.block.4.layer.0.SelfAttention                         | T5Attention                | 2 M
# 81  | model.encoder.block.4.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 82  | model.encoder.block.4.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 83  | model.encoder.block.4.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 84  | model.encoder.block.4.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 85  | model.encoder.block.4.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 86  | model.encoder.block.4.layer.0.dropout                               | Dropout                    | 0
# 87  | model.encoder.block.4.layer.1                                       | T5LayerFF                  | 15 M
# 88  | model.encoder.block.4.layer.1.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 89  | model.encoder.block.4.layer.1.DenseReluDense.wi_0                   | Linear                     | 5 M
# 90  | model.encoder.block.4.layer.1.DenseReluDense.wi_1                   | Linear                     | 5 M
# 91  | model.encoder.block.4.layer.1.DenseReluDense.wo                     | Linear                     | 5 M
# 92  | model.encoder.block.4.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 93  | model.encoder.block.4.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 94  | model.encoder.block.4.layer.1.dropout                               | Dropout                    | 0
# 95  | model.encoder.block.5                                               | T5Block                    | 18 M
# 96  | model.encoder.block.5.layer                                         | ModuleList                 | 18 M
# 97  | model.encoder.block.5.layer.0                                       | T5LayerSelfAttention       | 2 M
# 98  | model.encoder.block.5.layer.0.SelfAttention                         | T5Attention                | 2 M
# 99  | model.encoder.block.5.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 100 | model.encoder.block.5.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 101 | model.encoder.block.5.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 102 | model.encoder.block.5.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 103 | model.encoder.block.5.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 104 | model.encoder.block.5.layer.0.dropout                               | Dropout                    | 0
# 105 | model.encoder.block.5.layer.1                                       | T5LayerFF                  | 15 M
# 106 | model.encoder.block.5.layer.1.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 107 | model.encoder.block.5.layer.1.DenseReluDense.wi_0                   | Linear                     | 5 M
# 108 | model.encoder.block.5.layer.1.DenseReluDense.wi_1                   | Linear                     | 5 M
# 109 | model.encoder.block.5.layer.1.DenseReluDense.wo                     | Linear                     | 5 M
# 110 | model.encoder.block.5.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 111 | model.encoder.block.5.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 112 | model.encoder.block.5.layer.1.dropout                               | Dropout                    | 0
# 113 | model.encoder.block.6                                               | T5Block                    | 18 M
# 114 | model.encoder.block.6.layer                                         | ModuleList                 | 18 M
# 115 | model.encoder.block.6.layer.0                                       | T5LayerSelfAttention       | 2 M
# 116 | model.encoder.block.6.layer.0.SelfAttention                         | T5Attention                | 2 M
# 117 | model.encoder.block.6.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 118 | model.encoder.block.6.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 119 | model.encoder.block.6.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 120 | model.encoder.block.6.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 121 | model.encoder.block.6.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 122 | model.encoder.block.6.layer.0.dropout                               | Dropout                    | 0
# 123 | model.encoder.block.6.layer.1                                       | T5LayerFF                  | 15 M
# 124 | model.encoder.block.6.layer.1.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 125 | model.encoder.block.6.layer.1.DenseReluDense.wi_0                   | Linear                     | 5 M
# 126 | model.encoder.block.6.layer.1.DenseReluDense.wi_1                   | Linear                     | 5 M
# 127 | model.encoder.block.6.layer.1.DenseReluDense.wo                     | Linear                     | 5 M
# 128 | model.encoder.block.6.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 129 | model.encoder.block.6.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 130 | model.encoder.block.6.layer.1.dropout                               | Dropout                    | 0
# 131 | model.encoder.block.7                                               | T5Block                    | 18 M
# 132 | model.encoder.block.7.layer                                         | ModuleList                 | 18 M
# 133 | model.encoder.block.7.layer.0                                       | T5LayerSelfAttention       | 2 M
# 134 | model.encoder.block.7.layer.0.SelfAttention                         | T5Attention                | 2 M
# 135 | model.encoder.block.7.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 136 | model.encoder.block.7.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 137 | model.encoder.block.7.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 138 | model.encoder.block.7.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 139 | model.encoder.block.7.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 140 | model.encoder.block.7.layer.0.dropout                               | Dropout                    | 0
# 141 | model.encoder.block.7.layer.1                                       | T5LayerFF                  | 15 M
# 142 | model.encoder.block.7.layer.1.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 143 | model.encoder.block.7.layer.1.DenseReluDense.wi_0                   | Linear                     | 5 M
# 144 | model.encoder.block.7.layer.1.DenseReluDense.wi_1                   | Linear                     | 5 M
# 145 | model.encoder.block.7.layer.1.DenseReluDense.wo                     | Linear                     | 5 M
# 146 | model.encoder.block.7.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 147 | model.encoder.block.7.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 148 | model.encoder.block.7.layer.1.dropout                               | Dropout                    | 0
# 149 | model.encoder.block.8                                               | T5Block                    | 18 M
# 150 | model.encoder.block.8.layer                                         | ModuleList                 | 18 M
# 151 | model.encoder.block.8.layer.0                                       | T5LayerSelfAttention       | 2 M
# 152 | model.encoder.block.8.layer.0.SelfAttention                         | T5Attention                | 2 M
# 153 | model.encoder.block.8.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 154 | model.encoder.block.8.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 155 | model.encoder.block.8.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 156 | model.encoder.block.8.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 157 | model.encoder.block.8.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 158 | model.encoder.block.8.layer.0.dropout                               | Dropout                    | 0
# 159 | model.encoder.block.8.layer.1                                       | T5LayerFF                  | 15 M
# 160 | model.encoder.block.8.layer.1.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 161 | model.encoder.block.8.layer.1.DenseReluDense.wi_0                   | Linear                     | 5 M
# 162 | model.encoder.block.8.layer.1.DenseReluDense.wi_1                   | Linear                     | 5 M
# 163 | model.encoder.block.8.layer.1.DenseReluDense.wo                     | Linear                     | 5 M
# 164 | model.encoder.block.8.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 165 | model.encoder.block.8.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 166 | model.encoder.block.8.layer.1.dropout                               | Dropout                    | 0
# 167 | model.encoder.block.9                                               | T5Block                    | 18 M
# 168 | model.encoder.block.9.layer                                         | ModuleList                 | 18 M
# 169 | model.encoder.block.9.layer.0                                       | T5LayerSelfAttention       | 2 M
# 170 | model.encoder.block.9.layer.0.SelfAttention                         | T5Attention                | 2 M
# 171 | model.encoder.block.9.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 172 | model.encoder.block.9.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 173 | model.encoder.block.9.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 174 | model.encoder.block.9.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 175 | model.encoder.block.9.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 176 | model.encoder.block.9.layer.0.dropout                               | Dropout                    | 0
# 177 | model.encoder.block.9.layer.1                                       | T5LayerFF                  | 15 M
# 178 | model.encoder.block.9.layer.1.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 179 | model.encoder.block.9.layer.1.DenseReluDense.wi_0                   | Linear                     | 5 M
# 180 | model.encoder.block.9.layer.1.DenseReluDense.wi_1                   | Linear                     | 5 M
# 181 | model.encoder.block.9.layer.1.DenseReluDense.wo                     | Linear                     | 5 M
# 182 | model.encoder.block.9.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 183 | model.encoder.block.9.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 184 | model.encoder.block.9.layer.1.dropout                               | Dropout                    | 0
# 185 | model.encoder.block.10                                              | T5Block                    | 18 M
# 186 | model.encoder.block.10.layer                                        | ModuleList                 | 18 M
# 187 | model.encoder.block.10.layer.0                                      | T5LayerSelfAttention       | 2 M
# 188 | model.encoder.block.10.layer.0.SelfAttention                        | T5Attention                | 2 M
# 189 | model.encoder.block.10.layer.0.SelfAttention.q                      | Linear                     | 565 K
# 190 | model.encoder.block.10.layer.0.SelfAttention.k                      | Linear                     | 565 K
# 191 | model.encoder.block.10.layer.0.SelfAttention.v                      | Linear                     | 565 K
# 192 | model.encoder.block.10.layer.0.SelfAttention.o                      | Linear                     | 565 K
# 193 | model.encoder.block.10.layer.0.layer_norm                           | T5LayerNorm                | 1 K
# 194 | model.encoder.block.10.layer.0.dropout                              | Dropout                    | 0
# 195 | model.encoder.block.10.layer.1                                      | T5LayerFF                  | 15 M
# 196 | model.encoder.block.10.layer.1.DenseReluDense                       | T5DenseGatedGeluDense      | 15 M
# 197 | model.encoder.block.10.layer.1.DenseReluDense.wi_0                  | Linear                     | 5 M
# 198 | model.encoder.block.10.layer.1.DenseReluDense.wi_1                  | Linear                     | 5 M
# 199 | model.encoder.block.10.layer.1.DenseReluDense.wo                    | Linear                     | 5 M
# 200 | model.encoder.block.10.layer.1.DenseReluDense.dropout               | Dropout                    | 0
# 201 | model.encoder.block.10.layer.1.layer_norm                           | T5LayerNorm                | 1 K
# 202 | model.encoder.block.10.layer.1.dropout                              | Dropout                    | 0
# 203 | model.encoder.block.11                                              | T5Block                    | 18 M
# 204 | model.encoder.block.11.layer                                        | ModuleList                 | 18 M
# 205 | model.encoder.block.11.layer.0                                      | T5LayerSelfAttention       | 2 M
# 206 | model.encoder.block.11.layer.0.SelfAttention                        | T5Attention                | 2 M
# 207 | model.encoder.block.11.layer.0.SelfAttention.q                      | Linear                     | 565 K
# 208 | model.encoder.block.11.layer.0.SelfAttention.k                      | Linear                     | 565 K
# 209 | model.encoder.block.11.layer.0.SelfAttention.v                      | Linear                     | 565 K
# 210 | model.encoder.block.11.layer.0.SelfAttention.o                      | Linear                     | 565 K
# 211 | model.encoder.block.11.layer.0.layer_norm                           | T5LayerNorm                | 1 K
# 212 | model.encoder.block.11.layer.0.dropout                              | Dropout                    | 0
# 213 | model.encoder.block.11.layer.1                                      | T5LayerFF                  | 15 M
# 214 | model.encoder.block.11.layer.1.DenseReluDense                       | T5DenseGatedGeluDense      | 15 M
# 215 | model.encoder.block.11.layer.1.DenseReluDense.wi_0                  | Linear                     | 5 M
# 216 | model.encoder.block.11.layer.1.DenseReluDense.wi_1                  | Linear                     | 5 M
# 217 | model.encoder.block.11.layer.1.DenseReluDense.wo                    | Linear                     | 5 M
# 218 | model.encoder.block.11.layer.1.DenseReluDense.dropout               | Dropout                    | 0
# 219 | model.encoder.block.11.layer.1.layer_norm                           | T5LayerNorm                | 1 K
# 220 | model.encoder.block.11.layer.1.dropout                              | Dropout                    | 0
# 221 | model.encoder.final_layer_norm                                      | T5LayerNorm                | 1 K
# 222 | model.encoder.dropout                                               | Dropout                    | 0
# 223 | model.decoder                                                       | T5Stack                    | 81 M
# 224 | model.decoder.block                                                 | ModuleList                 | 81 M
# 225 | model.decoder.block.0                                               | T5Block                    | 20 M
# 226 | model.decoder.block.0.layer                                         | ModuleList                 | 20 M
# 227 | model.decoder.block.0.layer.0                                       | T5LayerSelfAttention       | 2 M
# 228 | model.decoder.block.0.layer.0.SelfAttention                         | T5Attention                | 2 M
# 229 | model.decoder.block.0.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 230 | model.decoder.block.0.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 231 | model.decoder.block.0.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 232 | model.decoder.block.0.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 233 | model.decoder.block.0.layer.0.SelfAttention.relative_attention_bias | Embedding                  | 192
# 234 | model.decoder.block.0.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 235 | model.decoder.block.0.layer.0.dropout                               | Dropout                    | 0
# 236 | model.decoder.block.0.layer.1                                       | T5LayerCrossAttention      | 2 M
# 237 | model.decoder.block.0.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 238 | model.decoder.block.0.layer.1.EncDecAttention.q                     | Linear                     | 565 K
# 239 | model.decoder.block.0.layer.1.EncDecAttention.k                     | Linear                     | 565 K
# 240 | model.decoder.block.0.layer.1.EncDecAttention.v                     | Linear                     | 565 K
# 241 | model.decoder.block.0.layer.1.EncDecAttention.o                     | Linear                     | 565 K
# 242 | model.decoder.block.0.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 243 | model.decoder.block.0.layer.1.dropout                               | Dropout                    | 0
# 244 | model.decoder.block.0.layer.2                                       | T5LayerFF                  | 15 M
# 245 | model.decoder.block.0.layer.2.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 246 | model.decoder.block.0.layer.2.DenseReluDense.wi_0                   | Linear                     | 5 M
# 247 | model.decoder.block.0.layer.2.DenseReluDense.wi_1                   | Linear                     | 5 M
# 248 | model.decoder.block.0.layer.2.DenseReluDense.wo                     | Linear                     | 5 M
# 249 | model.decoder.block.0.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 250 | model.decoder.block.0.layer.2.layer_norm                            | T5LayerNorm                | 1 K
# 251 | model.decoder.block.0.layer.2.dropout                               | Dropout                    | 0
# 252 | model.decoder.block.1                                               | T5Block                    | 20 M
# 253 | model.decoder.block.1.layer                                         | ModuleList                 | 20 M
# 254 | model.decoder.block.1.layer.0                                       | T5LayerSelfAttention       | 2 M
# 255 | model.decoder.block.1.layer.0.SelfAttention                         | T5Attention                | 2 M
# 256 | model.decoder.block.1.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 257 | model.decoder.block.1.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 258 | model.decoder.block.1.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 259 | model.decoder.block.1.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 260 | model.decoder.block.1.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 261 | model.decoder.block.1.layer.0.dropout                               | Dropout                    | 0
# 262 | model.decoder.block.1.layer.1                                       | T5LayerCrossAttention      | 2 M
# 263 | model.decoder.block.1.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 264 | model.decoder.block.1.layer.1.EncDecAttention.q                     | Linear                     | 565 K
# 265 | model.decoder.block.1.layer.1.EncDecAttention.k                     | Linear                     | 565 K
# 266 | model.decoder.block.1.layer.1.EncDecAttention.v                     | Linear                     | 565 K
# 267 | model.decoder.block.1.layer.1.EncDecAttention.o                     | Linear                     | 565 K
# 268 | model.decoder.block.1.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 269 | model.decoder.block.1.layer.1.dropout                               | Dropout                    | 0
# 270 | model.decoder.block.1.layer.2                                       | T5LayerFF                  | 15 M
# 271 | model.decoder.block.1.layer.2.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 272 | model.decoder.block.1.layer.2.DenseReluDense.wi_0                   | Linear                     | 5 M
# 273 | model.decoder.block.1.layer.2.DenseReluDense.wi_1                   | Linear                     | 5 M
# 274 | model.decoder.block.1.layer.2.DenseReluDense.wo                     | Linear                     | 5 M
# 275 | model.decoder.block.1.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 276 | model.decoder.block.1.layer.2.layer_norm                            | T5LayerNorm                | 1 K
# 277 | model.decoder.block.1.layer.2.dropout                               | Dropout                    | 0
# 278 | model.decoder.block.2                                               | T5Block                    | 20 M
# 279 | model.decoder.block.2.layer                                         | ModuleList                 | 20 M
# 280 | model.decoder.block.2.layer.0                                       | T5LayerSelfAttention       | 2 M
# 281 | model.decoder.block.2.layer.0.SelfAttention                         | T5Attention                | 2 M
# 282 | model.decoder.block.2.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 283 | model.decoder.block.2.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 284 | model.decoder.block.2.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 285 | model.decoder.block.2.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 286 | model.decoder.block.2.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 287 | model.decoder.block.2.layer.0.dropout                               | Dropout                    | 0
# 288 | model.decoder.block.2.layer.1                                       | T5LayerCrossAttention      | 2 M
# 289 | model.decoder.block.2.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 290 | model.decoder.block.2.layer.1.EncDecAttention.q                     | Linear                     | 565 K
# 291 | model.decoder.block.2.layer.1.EncDecAttention.k                     | Linear                     | 565 K
# 292 | model.decoder.block.2.layer.1.EncDecAttention.v                     | Linear                     | 565 K
# 293 | model.decoder.block.2.layer.1.EncDecAttention.o                     | Linear                     | 565 K
# 294 | model.decoder.block.2.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 295 | model.decoder.block.2.layer.1.dropout                               | Dropout                    | 0
# 296 | model.decoder.block.2.layer.2                                       | T5LayerFF                  | 15 M
# 297 | model.decoder.block.2.layer.2.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 298 | model.decoder.block.2.layer.2.DenseReluDense.wi_0                   | Linear                     | 5 M
# 299 | model.decoder.block.2.layer.2.DenseReluDense.wi_1                   | Linear                     | 5 M
# 300 | model.decoder.block.2.layer.2.DenseReluDense.wo                     | Linear                     | 5 M
# 301 | model.decoder.block.2.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 302 | model.decoder.block.2.layer.2.layer_norm                            | T5LayerNorm                | 1 K
# 303 | model.decoder.block.2.layer.2.dropout                               | Dropout                    | 0
# 304 | model.decoder.block.3                                               | T5Block                    | 20 M
# 305 | model.decoder.block.3.layer                                         | ModuleList                 | 20 M
# 306 | model.decoder.block.3.layer.0                                       | T5LayerSelfAttention       | 2 M
# 307 | model.decoder.block.3.layer.0.SelfAttention                         | T5Attention                | 2 M
# 308 | model.decoder.block.3.layer.0.SelfAttention.q                       | Linear                     | 565 K
# 309 | model.decoder.block.3.layer.0.SelfAttention.k                       | Linear                     | 565 K
# 310 | model.decoder.block.3.layer.0.SelfAttention.v                       | Linear                     | 565 K
# 311 | model.decoder.block.3.layer.0.SelfAttention.o                       | Linear                     | 565 K
# 312 | model.decoder.block.3.layer.0.layer_norm                            | T5LayerNorm                | 1 K
# 313 | model.decoder.block.3.layer.0.dropout                               | Dropout                    | 0
# 314 | model.decoder.block.3.layer.1                                       | T5LayerCrossAttention      | 2 M
# 315 | model.decoder.block.3.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 316 | model.decoder.block.3.layer.1.EncDecAttention.q                     | Linear                     | 565 K
# 317 | model.decoder.block.3.layer.1.EncDecAttention.k                     | Linear                     | 565 K
# 318 | model.decoder.block.3.layer.1.EncDecAttention.v                     | Linear                     | 565 K
# 319 | model.decoder.block.3.layer.1.EncDecAttention.o                     | Linear                     | 565 K
# 320 | model.decoder.block.3.layer.1.layer_norm                            | T5LayerNorm                | 1 K
# 321 | model.decoder.block.3.layer.1.dropout                               | Dropout                    | 0
# 322 | model.decoder.block.3.layer.2                                       | T5LayerFF                  | 15 M
# 323 | model.decoder.block.3.layer.2.DenseReluDense                        | T5DenseGatedGeluDense      | 15 M
# 324 | model.decoder.block.3.layer.2.DenseReluDense.wi_0                   | Linear                     | 5 M
# 325 | model.decoder.block.3.layer.2.DenseReluDense.wi_1                   | Linear                     | 5 M
# 326 | model.decoder.block.3.layer.2.DenseReluDense.wo                     | Linear                     | 5 M
# 327 | model.decoder.block.3.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 328 | model.decoder.block.3.layer.2.layer_norm                            | T5LayerNorm                | 1 K
# 329 | model.decoder.block.3.layer.2.dropout                               | Dropout                    | 0
# 330 | model.decoder.final_layer_norm                                      | T5LayerNorm                | 1 K
# 331 | model.decoder.dropout                                               | Dropout                    | 0
# 332 | model.lm_head                                                       | Linear                     | 565 K
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/zihao/anaconda3/envs/py37/lib/python3.7/site-packages/transformers/models/byt5/tokenization_byt5.py:146: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   f"This sequence already has {self.eos_token}. In future versions this behavior may lead to duplicated eos tokens being added."
# train:
# 269913
# Epoch 1:  34%|███▍      | 103317/303653 [6:19:02<12:14:59,  4.54it/s, loss=0.000, v_num=17]

# %%
model.model.save_pretrained('t5_small_danmu_classify_subCate')
